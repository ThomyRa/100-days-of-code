# %%
import random
import os

def initial_hands():
    initial_player_hand = []
    initial_dealer_hand = []

    initial_player_hand += [random.choice(cards), random.choice(cards)]
    initial_dealer_hand += [random.choice(cards), random.choice(cards)]
    
    print(f"Your cards: [{initial_player_hand}], current score: {sum(initial_player_hand)}")
    print(f"Computer's first card: {initial_dealer_hand[0]}")
    return {'player' : initial_player_hand, 'dealer' : initial_dealer_hand}

def new_card(dict_hands, participant):
    for person in dict_hands:
        if person == participant:
            dict_hands[person] += [random.choice(cards)]
    return dict_hands

def play_again():
    again = input("Do you want to play another game? Type 'y' or 'n' ")
    if again == 'y':
        return True
    else:
        return False

cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
new_game = True
while new_game:
    os.system('clear')
    hands = initial_hands()

    flag = False
    while flag == False:
        more_cards = input("Type 'y' to get another card, type 'n' to pass: ")
        if more_cards == 'y':
            hands = new_card(hands, 'player')
            print(f"Your cards {hands['player']}, current score: {sum(hands['player'])}")
            print(f"Computer's first card: {hands['dealer'][0]}")
            if sum(hands['player']) > 21:
                print(f"Your cards {hands['player']}, current score: {sum(hands['player'])}")
                print(f"Computer's cards {hands['dealer']}, current score: {sum(hands['dealer'])}")
                print("You lose :(")
                new_game = play_again()            
        else:
            flag = True

    player_score = sum(hands['player'])
    dealer_score = sum(hands['dealer'])
    if dealer_score >= player_score:
        print(f"Your cards {hands['player']}, current score: {sum(hands['player'])}")
        print(f"Computer's cards {hands['dealer']}, current score: {sum(hands['dealer'])}")
        print("You lose :(")
        new_game = play_again()
    else:
        while dealer_score < 17:
            hands = new_card(hands, 'dealer')
            dealer_score = sum(hands['dealer'])
            if dealer_score > 21:
                print(f"Your cards {hands['player']}, current score: {sum(hands['player'])}")
                print(f"Computer's cards {hands['dealer']}, current score: {sum(hands['dealer'])}")
                print("You win :)")
                new_game = play_again()
            elif dealer_score > 17 and dealer_score < 21:
                hands = new_card(hands, 'dealer')
                print(f"Your cards {hands['player']}, current score: {sum(hands['player'])}")
                print(f"Computer's cards {hands['dealer']}, current score: {sum(hands['dealer'])}")
                if dealer_score > player_score:
                    print(f"Your cards {hands['player']}, current score: {sum(hands['player'])}")
                    print(f"Computer's cards {hands['dealer']}, current score: {sum(hands['dealer'])}")
                    print("You win :)")
                    new_game = play_again()
            else:
                print(f"Your cards {hands['player']}, current score: {sum(hands['player'])}")
                print(f"Computer's cards {hands['dealer']}, current score: {sum(hands['dealer'])}")
                print("You lose :)")
# Out:
# Your cards: [[10, 2]], current score: 12
# Computer's first card: 10
# Your cards [10, 2, 4], current score: 16
# Computer's first card: 10
# Your cards [10, 2, 4], current score: 16
# Computer's cards [10, 2, 3], current score: 15
# You lose :)
# Your cards [10, 2, 4], current score: 16
# Computer's cards [10, 2, 3, 11], current score: 26
# You win :)

# %%
import random
import os

def initial_hands():
    initial_player_hand = []
    initial_dealer_hand = []

    initial_player_hand += [random.choice(cards), random.choice(cards)]
    initial_dealer_hand += [random.choice(cards), random.choice(cards)]
    
    print(f"Your cards: [{initial_player_hand}], current score: {sum(initial_player_hand)}")
    print(f"Computer's first card: {initial_dealer_hand[0]}")
    return {'player' : initial_player_hand, 'dealer' : initial_dealer_hand}

def new_card(dict_hands, participant):
    for person in dict_hands:
        if person == participant:
            dict_hands[person] += [random.choice(cards)]
    return dict_hands

def play_again():
    again = input("Do you want to play another game? Type 'y' or 'n' ")
    if again == 'y':
        return True
    else:
        return False

cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
new_game = True
while new_game:
    os.system('clear')
    hands = initial_hands()

    flag = False
    while flag == False:
        more_cards = input("Type 'y' to get another card, type 'n' to pass: ")
        if more_cards == 'y':
            hands = new_card(hands, 'player')
            print(f"Your cards {hands['player']}, current score: {sum(hands['player'])}")
            print(f"Computer's first card: {hands['dealer'][0]}")
            if sum(hands['player']) > 21:
                print(f"Your cards {hands['player']}, current score: {sum(hands['player'])}")
                print(f"Computer's cards {hands['dealer']}, current score: {sum(hands['dealer'])}")
                print("You lose :(")
                new_game = play_again()            
        else:
            flag = True

    player_score = sum(hands['player'])
    dealer_score = sum(hands['dealer'])
    if dealer_score >= player_score:
        print(f"Your cards {hands['player']}, current score: {sum(hands['player'])}")
        print(f"Computer's cards {hands['dealer']}, current score: {sum(hands['dealer'])}")
        print("You lose :(")
        new_game = play_again()
    else:
        while dealer_score < 17:
            hands = new_card(hands, 'dealer')
            dealer_score = sum(hands['dealer'])
            if dealer_score > 21:
                print(f"Your cards {hands['player']}, current score: {sum(hands['player'])}")
                print(f"Computer's cards {hands['dealer']}, current score: {sum(hands['dealer'])}")
                print("You win :)")
                new_game = play_again()
            elif dealer_score > 17 and dealer_score < 21:
                hands = new_card(hands, 'dealer')
                print(f"Your cards {hands['player']}, current score: {sum(hands['player'])}")
                print(f"Computer's cards {hands['dealer']}, current score: {sum(hands['dealer'])}")
                if dealer_score > player_score:
                    print(f"Your cards {hands['player']}, current score: {sum(hands['player'])}")
                    print(f"Computer's cards {hands['dealer']}, current score: {sum(hands['dealer'])}")
                    print("You win :)")
                    new_game = play_again()
            else:
                print(f"Your cards {hands['player']}, current score: {sum(hands['player'])}")
                print(f"Computer's cards {hands['dealer']}, current score: {sum(hands['dealer'])}")
                print("You lose :)")
# Out:
# Your cards: [[10, 11]], current score: 21
# Computer's first card: 10
# Your cards: [[3, 3]], current score: 6
# Computer's first card: 7
# Your cards [3, 3], current score: 6
# Computer's cards [7, 8], current score: 15
# You lose :(
